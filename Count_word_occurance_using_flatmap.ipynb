# %%
#Counting Word Occurance using flatMap()

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\shash\myapps\lib\site-packages (4.1.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\shash\myapps\lib\site-packages (from pyspark) (0.10.9.9)

# %%
from pyspark import SparkConf, SparkContext
conf=SparkConf().setMaster("local").setAppName("word_count")
#sc=SparkContext(conf = conf)

# %%
input = sc.textFile("file.txt")
words = input.flatMap(lambda x: x.split())
word_count = words.countByValue()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 input = sc.textFile("file.txt")
#       2 words = input.flatMap(lambda x: x.split())
#       3 word_count = words.countByValue()
#
# NameError: name 'sc' is not defined

# %%
for word, count in word_count.item():
    cleanWord=word.encode("ascii","ignore")
    if (cleanWord):
        print(cleanWord.decode() + " " + str(count))
